# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from api.spotify_client import search_tracks

# %%
tracks = search_tracks("arijit singh", limit=5)

for t in tracks:
    print(t)
# Out:
# {'track_name': 'Phir Bhi Tumko Chaahunga', 'artist': 'Mithoon', 'track_id': '1fcCPXmH4vUzG6UQTTjZp5'}
# {'track_name': 'Agar Tum Saath Ho (From "Tamasha")', 'artist': 'Alka Yagnik', 'track_id': '2FCXQHugkoHE1K3tiDu8pu'}
# {'track_name': 'Gehra Hua (From "Dhurandhar")', 'artist': 'Shashwat Sachdev', 'track_id': '0Y6YW1552df031DjV8qBHv'}
# {'track_name': 'Satranga (From "ANIMAL")', 'artist': 'Arijit Singh', 'track_id': '3yHyiUDJdz02FZ6jfUbsmY'}
# {'track_name': 'Zaalima', 'artist': 'Arijit Singh', 'track_id': '4MU4Kfkd9EnkArK2ocQyqK'}

# %%
from api.spotify_client import get_playlist_tracks, get_audio_features
import pandas as pd

# %%
hindi_playlists = [
    "37i9dQZF1DX0XUsuxWHRQd",
    "37i9dQZF1DX4qDB8c4sXtG"
]

telugu_playlists = [
    "37i9dQZF1DX1i3hvzHpcQV",
    "37i9dQZF1DX3bcfiyW6h5p"
]

western_playlists = [
    "37i9dQZF1DXcBWIGoYBM5M",
    "37i9dQZF1DX4dyzvuaRJ0n"
]
